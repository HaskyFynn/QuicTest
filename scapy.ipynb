# %%
from scapy.all import *

from hparser import parse_short_header, parse_long_header, parse_first_layers
from traceback import format_exc
from scapy.layers.inet import UDP, IP
from config import ETH_HLEN, UDP_HLEN

# %%
pcap = rdpcap('quic_pkt.pcap')
a = pcap[0]
port = 6121  # Initial port

for packet in a:
    try:
        # Check if packet has a UDP layer
        if "UDP" in packet:
            quic_bytes = bytes(packet["UDP"])[8:]

            # Parse QUIC Header
            payload_offset = ETH_HLEN + packet[IP].ihl + UDP_HLEN
            parsed_header, _ = parse_long_header(int.from_bytes(quic_bytes[:4], 'big'), quic_bytes, payload_offset)  # Assuming long header for this example

            # Modify connection IDs
            parsed_header["src_conn_id_hex"] = "994befda" 
            parsed_header["dest_conn_id_hex"] = "994befda"  

            # Craft new packet with modified connection IDs
            new_quic_bytes = bytearray(quic_bytes)

            quic_packet = IP(src="10.10.10.69", dst="10.10.10.47") / UDP(sport=443, dport=port) / Raw(load=new_quic_bytes)
            for i in range(1,2):
                send(quic_packet, verbose=True, count=1)
                time.sleep(1)
    except IndexError:
        # Handle potential IndexError if packet doesn't have a UDP layer
        pass
# Out:
# .
# Sent 1 packets.

# %%
from hparser import parse_long_header 
from hparser import parse_short_header
from hparser import parse_first_layers
from config import ETH_HLEN, UDP_HLEN


# Provided functions for parsing QUIC headers
def parse_quic_packet(packet_bytearray: bytearray) -> None:
    # Parse initial layers (IP, UDP)
    layers_info, payload_offset = parse_first_layers(packet_bytearray)
    
    # Check if UDP port matches QUIC 
    #if layers_info["port_dst"] != 6121 :  
        #print(f"Skipping packet: Non-standard UDP port ({layers_info['port_dst']})")
        #return

    # Parse QUIC header (short or long)
    first_byte = packet_bytearray[payload_offset]
    if first_byte & 0x80:  # Check for Long Header format
        parsed_header, _ = parse_long_header(first_byte, packet_bytearray, payload_offset)
    else:
        parsed_header, _ = parse_short_header(first_byte, packet_bytearray, payload_offset)

    # Extract connection IDs and type (handle potential KeyError)
    try:
        src_conn_id_int = parsed_header["src_conn_id_int"]
        src_conn_id_hex = parsed_header["src_conn_id"]
        dest_conn_id_int = parsed_header["dest_conn_id_int"]
        dest_conn_id_hex = parsed_header["dest_conn_id"]
        packet_type = parsed_header["packet_type"]
    except KeyError as e:
        print(f"Error parsing header: {e}")
        src_conn_id_int, src_conn_id_hex, dest_conn_id_int, dest_conn_id_hex, packet_type = None, None, None, None, None

    # Print information
    print(f"Source Connection ID (int): {src_conn_id_int}")
    print(f"Source Connection ID (hex): {src_conn_id_hex}")
    print(f"Destination Connection ID (int): {dest_conn_id_int}")
    print(f"Destination Connection ID (hex): {dest_conn_id_hex}")
    print(f"Packet Type: {packet_type}")
    print("-" * 20)  # separator between packets



# Open the PCAP file
with open('quic_traffic.pcap', 'rb') as f:
    pcap_data = f.read()

# Loop through packets in the PCAP data
for packet in rdpcap("quic_traffic.pcap")[4]:
    parse_quic_packet(bytes(packet))
# Out:
# Source Connection ID (int): 3975027447
# Source Connection ID (hex): ecee1af7
# Destination Connection ID (int): 3026345635167337033474437852111091316889245497
# Destination Connection ID (hex): 87b4be7e937036e6957a97f136118f32c05739
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2507681006
# Source Connection ID (hex): 95782cee
# Destination Connection ID (int): 3975027447
# Destination Connection ID (hex): ecee1af7
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2507681006
# Source Connection ID (hex): 95782cee
# Destination Connection ID (int): 3975027447
# Destination Connection ID (hex): ecee1af7
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3975027447
# Source Connection ID (hex): ecee1af7
# Destination Connection ID (int): 2507681006
# Destination Connection ID (hex): 95782cee
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3975027447
# Source Connection ID (hex): ecee1af7
# Destination Connection ID (int): 3042057600
# Destination Connection ID (hex): b5521d80
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 1368067302
# Source Connection ID (hex): 518b0ce6
# Destination Connection ID (int): 16915815086142451489
# Destination Connection ID (hex): eac10c326fb6ef21
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3790777847
# Source Connection ID (hex): e1f2adf7
# Destination Connection ID (int): 1368067302
# Destination Connection ID (hex): 518b0ce6
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3790777847
# Source Connection ID (hex): e1f2adf7
# Destination Connection ID (int): 1368067302
# Destination Connection ID (hex): 518b0ce6
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 1368067302
# Source Connection ID (hex): 518b0ce6
# Destination Connection ID (int): 3790777847
# Destination Connection ID (hex): e1f2adf7
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1368067302
# Source Connection ID (hex): 518b0ce6
# Destination Connection ID (int): 3807099904
# Destination Connection ID (hex): e2ebbc00
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 4166671031
# Source Connection ID (hex): f85a5ab7
# Destination Connection ID (int): 630401935673018456757614
# Destination Connection ID (hex): 857e284c0202346c556e
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3906419068
# Source Connection ID (hex): e8d7397c
# Destination Connection ID (int): 4166671031
# Destination Connection ID (hex): f85a5ab7
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3906419068
# Source Connection ID (hex): e8d7397c
# Destination Connection ID (int): 4166671031
# Destination Connection ID (hex): f85a5ab7
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 4166671031
# Source Connection ID (hex): f85a5ab7
# Destination Connection ID (int): 3906419068
# Destination Connection ID (hex): e8d7397c
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 4166671031
# Source Connection ID (hex): f85a5ab7
# Destination Connection ID (int): 1711645067
# Destination Connection ID (hex): 6605a18b
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2274970321
# Source Connection ID (hex): 87994ad1
# Destination Connection ID (int): 327435532304068010653950843209281765216
# Destination Connection ID (hex): f655ca26a379a88298efe6865ea8ff60
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1559197501
# Source Connection ID (hex): 5cef773d
# Destination Connection ID (int): 2274970321
# Destination Connection ID (hex): 87994ad1
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1559197501
# Source Connection ID (hex): 5cef773d
# Destination Connection ID (int): 2274970321
# Destination Connection ID (hex): 87994ad1
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2274970321
# Source Connection ID (hex): 87994ad1
# Destination Connection ID (int): 1559197501
# Destination Connection ID (hex): 5cef773d
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2274970321
# Source Connection ID (hex): 87994ad1
# Destination Connection ID (int): 2970127798
# Destination Connection ID (hex): b1088db6
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3972617558
# Source Connection ID (hex): ecc95556
# Destination Connection ID (int): 632922087936226875601211
# Destination Connection ID (hex): 8606c66f6d0ec6f6f13b
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2072072768
# Source Connection ID (hex): 7b815240
# Destination Connection ID (int): 3972617558
# Destination Connection ID (hex): ecc95556
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2072072768
# Source Connection ID (hex): 7b815240
# Destination Connection ID (int): 3972617558
# Destination Connection ID (hex): ecc95556
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3972617558
# Source Connection ID (hex): ecc95556
# Destination Connection ID (int): 2072072768
# Destination Connection ID (hex): 7b815240
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3972617558
# Source Connection ID (hex): ecc95556
# Destination Connection ID (int): 4091006040
# Destination Connection ID (hex): f3d7cc58
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3744500969
# Source Connection ID (hex): df308ce9
# Destination Connection ID (int): 3594261387504632521870652438190463
# Destination Connection ID (hex): b135f4e831184dd5dba4de27997f
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2420996999
# Source Connection ID (hex): 904d7b87
# Destination Connection ID (int): 3744500969
# Destination Connection ID (hex): df308ce9
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2420996999
# Source Connection ID (hex): 904d7b87
# Destination Connection ID (int): 3744500969
# Destination Connection ID (hex): df308ce9
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3744500969
# Source Connection ID (hex): df308ce9
# Destination Connection ID (int): 2420996999
# Destination Connection ID (hex): 904d7b87
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3744500969
# Source Connection ID (hex): df308ce9
# Destination Connection ID (int): 56659887
# Destination Connection ID (hex): 03608faf
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 900011272
# Source Connection ID (hex): 35a51508
# Destination Connection ID (int): 3612491267311138827491487765484
# Destination Connection ID (hex): 2d9896bd452eb7cf9ae98bd3ec
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1166154335
# Source Connection ID (hex): 45821a5f
# Destination Connection ID (int): 900011272
# Destination Connection ID (hex): 35a51508
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1166154335
# Source Connection ID (hex): 45821a5f
# Destination Connection ID (int): 900011272
# Destination Connection ID (hex): 35a51508
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 900011272
# Source Connection ID (hex): 35a51508
# Destination Connection ID (int): 1166154335
# Destination Connection ID (hex): 45821a5f
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 900011272
# Source Connection ID (hex): 35a51508
# Destination Connection ID (int): 3521985638
# Destination Connection ID (hex): d1ed3c66
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 1237759377
# Source Connection ID (hex): 49c6b591
# Destination Connection ID (int): 1301766269347109824363671964354039
# Destination Connection ID (hex): 402e99ac145456e7337efea005f7
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1216959073
# Source Connection ID (hex): 48895261
# Destination Connection ID (int): 1237759377
# Destination Connection ID (hex): 49c6b591
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1216959073
# Source Connection ID (hex): 48895261
# Destination Connection ID (int): 1237759377
# Destination Connection ID (hex): 49c6b591
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 1237759377
# Source Connection ID (hex): 49c6b591
# Destination Connection ID (int): 1216959073
# Destination Connection ID (hex): 48895261
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1237759377
# Source Connection ID (hex): 49c6b591
# Destination Connection ID (int): 971433071
# Destination Connection ID (hex): 39e6e46f
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3993645863
# Source Connection ID (hex): ee0a3327
# Destination Connection ID (int): 64261582654726924076207119339764558212611
# Destination Connection ID (hex): bcd90aa17f158363ab75ae33cb2f6e2e03
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2626026877
# Source Connection ID (hex): 9c85fd7d
# Destination Connection ID (int): 3993645863
# Destination Connection ID (hex): ee0a3327
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2626026877
# Source Connection ID (hex): 9c85fd7d
# Destination Connection ID (int): 3993645863
# Destination Connection ID (hex): ee0a3327
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3993645863
# Source Connection ID (hex): ee0a3327
# Destination Connection ID (int): 2626026877
# Destination Connection ID (hex): 9c85fd7d
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3993645863
# Source Connection ID (hex): ee0a3327
# Destination Connection ID (int): 2845862858
# Destination Connection ID (hex): a9a06bca
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2396272060
# Source Connection ID (hex): 8ed435bc
# Destination Connection ID (int): 2477956164531476382994900543473151311298372068
# Destination Connection ID (hex): 6f1d8aaeb702eed16d626b39f0ae69648f21e4
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2286927672
# Source Connection ID (hex): 884fbf38
# Destination Connection ID (int): 2396272060
# Destination Connection ID (hex): 8ed435bc
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2286927672
# Source Connection ID (hex): 884fbf38
# Destination Connection ID (int): 2396272060
# Destination Connection ID (hex): 8ed435bc
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2396272060
# Source Connection ID (hex): 8ed435bc
# Destination Connection ID (int): 2286927672
# Destination Connection ID (hex): 884fbf38
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2396272060
# Source Connection ID (hex): 8ed435bc
# Destination Connection ID (int): 1731272648
# Destination Connection ID (hex): 67311fc8
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 798386799
# Source Connection ID (hex): 2f966a6f
# Destination Connection ID (int): 13772746760591526989209532049202175887755427
# Destination Connection ID (hex): 9e1a770c44bfd6ce8d302da50046516748a3
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2138928486
# Source Connection ID (hex): 7f7d7566
# Destination Connection ID (int): 798386799
# Destination Connection ID (hex): 2f966a6f
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2138928486
# Source Connection ID (hex): 7f7d7566
# Destination Connection ID (int): 798386799
# Destination Connection ID (hex): 2f966a6f
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 798386799
# Source Connection ID (hex): 2f966a6f
# Destination Connection ID (int): 2138928486
# Destination Connection ID (hex): 7f7d7566
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 798386799
# Source Connection ID (hex): 2f966a6f
# Destination Connection ID (int): 1841898582
# Destination Connection ID (hex): 6dc92456
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2709779364
# Source Connection ID (hex): a183f3a4
# Destination Connection ID (int): 62440547125487750750217231572
# Destination Connection ID (hex): c9c19c2a3b5ba1697154dcd4
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1034241760
# Source Connection ID (hex): 3da546e0
# Destination Connection ID (int): 2709779364
# Destination Connection ID (hex): a183f3a4
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1034241760
# Source Connection ID (hex): 3da546e0
# Destination Connection ID (int): 2709779364
# Destination Connection ID (hex): a183f3a4
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2709779364
# Source Connection ID (hex): a183f3a4
# Destination Connection ID (int): 1034241760
# Destination Connection ID (hex): 3da546e0
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2709779364
# Source Connection ID (hex): a183f3a4
# Destination Connection ID (int): 1327009891
# Destination Connection ID (hex): 4f189063
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3552611409
# Source Connection ID (hex): d3c08c51
# Destination Connection ID (int): 2133125104273667561064
# Destination Connection ID (hex): 73a30ebc8e440a9668
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 662183318
# Source Connection ID (hex): 27781d96
# Destination Connection ID (int): 3552611409
# Destination Connection ID (hex): d3c08c51
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 662183318
# Source Connection ID (hex): 27781d96
# Destination Connection ID (int): 3552611409
# Destination Connection ID (hex): d3c08c51
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3552611409
# Source Connection ID (hex): d3c08c51
# Destination Connection ID (int): 662183318
# Destination Connection ID (hex): 27781d96
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3552611409
# Source Connection ID (hex): d3c08c51
# Destination Connection ID (int): 3695258887
# Destination Connection ID (hex): dc412d07
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3372847281
# Source Connection ID (hex): c90990b1
# Destination Connection ID (int): 449416351516320785498439548816085911325936535
# Destination Connection ID (hex): 14270bf4b841141a012eb9d640b9a1b3388b97
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2160999376
# Source Connection ID (hex): 80ce3bd0
# Destination Connection ID (int): 3372847281
# Destination Connection ID (hex): c90990b1
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2160999376
# Source Connection ID (hex): 80ce3bd0
# Destination Connection ID (int): 3372847281
# Destination Connection ID (hex): c90990b1
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 3372847281
# Source Connection ID (hex): c90990b1
# Destination Connection ID (int): 2160999376
# Destination Connection ID (hex): 80ce3bd0
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3372847281
# Source Connection ID (hex): c90990b1
# Destination Connection ID (int): 273379419
# Destination Connection ID (hex): 104b705b
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2373630068
# Source Connection ID (hex): 8d7ab874
# Destination Connection ID (int): 6992090007965290543
# Destination Connection ID (hex): 6108e4d10a54502f
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1555545883
# Source Connection ID (hex): 5cb7bf1b
# Destination Connection ID (int): 2373630068
# Destination Connection ID (hex): 8d7ab874
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1555545883
# Source Connection ID (hex): 5cb7bf1b
# Destination Connection ID (int): 2373630068
# Destination Connection ID (hex): 8d7ab874
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2373630068
# Source Connection ID (hex): 8d7ab874
# Destination Connection ID (int): 1555545883
# Destination Connection ID (hex): 5cb7bf1b
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2373630068
# Source Connection ID (hex): 8d7ab874
# Destination Connection ID (int): 3221141729
# Destination Connection ID (hex): bffeb8e1
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 4188020782
# Source Connection ID (hex): f9a0202e
# Destination Connection ID (int): 33377436261859215912055698031202546075788
# Destination Connection ID (hex): 6216646577ca4871ee13b1a30c2d61c88c
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1093860264
# Source Connection ID (hex): 4132fba8
# Destination Connection ID (int): 4188020782
# Destination Connection ID (hex): f9a0202e
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1093860264
# Source Connection ID (hex): 4132fba8
# Destination Connection ID (int): 4188020782
# Destination Connection ID (hex): f9a0202e
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 4188020782
# Source Connection ID (hex): f9a0202e
# Destination Connection ID (int): 1093860264
# Destination Connection ID (hex): 4132fba8
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 4188020782
# Source Connection ID (hex): f9a0202e
# Destination Connection ID (int): 245680192
# Destination Connection ID (hex): 0ea4c840
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2209444990
# Source Connection ID (hex): 83b1747e
# Destination Connection ID (int): 302151320261613171736306693352600398540
# Destination Connection ID (hex): e3503a403eab39c16d351f58b2186acc
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2697450978
# Source Connection ID (hex): a0c7d5e2
# Destination Connection ID (int): 2209444990
# Destination Connection ID (hex): 83b1747e
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2697450978
# Source Connection ID (hex): a0c7d5e2
# Destination Connection ID (int): 2209444990
# Destination Connection ID (hex): 83b1747e
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2209444990
# Source Connection ID (hex): 83b1747e
# Destination Connection ID (int): 2697450978
# Destination Connection ID (hex): a0c7d5e2
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2209444990
# Source Connection ID (hex): 83b1747e
# Destination Connection ID (int): 2506475378
# Destination Connection ID (hex): 9565c772
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 1812141163
# Source Connection ID (hex): 6c03146b
# Destination Connection ID (int): 774900051806139762543391
# Destination Connection ID (hex): a4176a7dc140710b0b1f
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1404991984
# Source Connection ID (hex): 53be79f0
# Destination Connection ID (int): 1812141163
# Destination Connection ID (hex): 6c03146b
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1404991984
# Source Connection ID (hex): 53be79f0
# Destination Connection ID (int): 1812141163
# Destination Connection ID (hex): 6c03146b
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 1812141163
# Source Connection ID (hex): 6c03146b
# Destination Connection ID (int): 1404991984
# Destination Connection ID (hex): 53be79f0
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 1812141163
# Source Connection ID (hex): 6c03146b
# Destination Connection ID (int): 1095065574
# Destination Connection ID (hex): 41455fe6
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2790489958
# Source Connection ID (hex): a6537f66
# Destination Connection ID (int): 4952894602116795184074534360842895403896521858
# Destination Connection ID (hex): de187110011062483d3a65714df65d3c6fc482
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3119561045
# Source Connection ID (hex): b9f0b955
# Destination Connection ID (int): 2790489958
# Destination Connection ID (hex): a6537f66
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 3119561045
# Source Connection ID (hex): b9f0b955
# Destination Connection ID (int): 2790489958
# Destination Connection ID (hex): a6537f66
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Source Connection ID (int): 2790489958
# Source Connection ID (hex): a6537f66
# Destination Connection ID (int): 3119561045
# Destination Connection ID (hex): b9f0b955
# Packet Type: Initial
# --------------------
# Source Connection ID (int): 2790489958
# Source Connection ID (hex): a6537f66
# Destination Connection ID (int): 3305520248
# Destination Connection ID (hex): c5063c78
# Packet Type: Handshake
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------
# Error parsing header: 'src_conn_id_int'
# Source Connection ID (int): None
# Source Connection ID (hex): None
# Destination Connection ID (int): None
# Destination Connection ID (hex): None
# Packet Type: None
# --------------------

# %%
# from typing import List, Dict
# from util import get_varint
# from flags import flags
# from frame_types import get_frame_name, APPLICATION_CLOSE, \
#     CONNECTION_CLOSE, NEW_CONNECTION_ID, PADDING, \
#     RETIRE_CONNECTION_ID, STREAM, STREAM_DATA_BLOCKED, \
#     STREAMS_BLOCKED_BIDI, STREAMS_BLOCKED_UNI, ACK
# from config import MAX_STREAM_SIZE, SEAL_BYTES, LAST_FRAME_PADDING
# from fparser import parse_frames_rec

# # Import Scapy for PCAP reading
# from scapy.all import rdpcap

# def parse_frames(packet_bytearray: bytearray, payload_offset: int) -> List[Dict]:
#     frames = []
#     result = parse_frames_rec(packet_bytearray, payload_offset, frames)

#     return frames, result


# def generate_result(status, reason, payload_offset: int, remaining_length: int) -> dict:
#     return {
#         "status": status,
#         "reason": reason,
#         "payload_offset": payload_offset,
#         "remaining_length": remaining_length
#     }

# # Open the PCAP file with Scapy
# packets = rdpcap("quic_traffic.pcap")[7]

# # Loop through packets
# for packet in packets:
#     # Extract raw packet data
#     packet_data = bytes(packet)

#     # Define starting offset
#     payload_offset = 0

#     # Parse frames in the packet
#     frames, result = parse_frames(packet_data, payload_offset)

#     # Analyze the results
#     if result["status"] == 200:  # Successfully parsed all frames
#         print(f"Packet successfully parsed. Found {len(frames)} frames.")
#         for frame in frames:
#             print(f"  - Frame Name: {frame['frame_name']}")
#             print(f"    - Frame Type: {frame.get('frame_type', '')}")
#             # Access other frame details based on frame type

#     else:
#         print(f"Error parsing packet: {result['reason']}")

# %%
pcap = rdpcap('new_quic.pcap')
a = pcap[0]  #initial packet type
# send(a, verbose =True , count=1)

for packet in a:
  
    try:
        # Check if packet has a UDP layer
        if UDP in packet:
             # Parse QUIC Header (assuming it's in the payload)
            payload_offset = ETH_HLEN + packet[IP].ihl + UDP_HLEN
            parsed_header, _ = parse_long_header(int.from_bytes(quic_bytes[:4], 'big'), quic_bytes, payload_offset)  # Assuming long header for this example

            # Modify connection IDs (replace with desired test values)
            parsed_header["src_conn_id_hex"] =  "55a520d4" # Replace with your test source connection ID
            parsed_header["dest_conn_id_hex"] = "92b221ec"  # Replace with your test destination connection ID

            # Craft new packet with modified connection IDs
            new_quic_bytes = bytearray(quic_bytes)
            
            # Modify the relevant bytes in quic_bytes

            quic_packet = IP(src="10.10.10.69", dst="10.10.10.66") / UDP(sport=443, dport=6121) / Raw(load=new_quic_bytes)
            send(quic_packet, verbose=True, count=1)
    except IndexError:
        # Handle potential IndexError if packet doesn't have a UDP layer
        pass

# %%
import scapy.all
from scapy.all import sniff, wrpcap
from typing import List, Dict
from scapy.layers.inet import UDP

import base64
from scapy.all import *
import os
import random

from hparser import parse_short_header, parse_long_header

from config import ETH_HLEN, UDP_HLEN

# Import functions from the provided frame_parser code
from fparser import parse_frames, generate_result


def parse_quic_packets(pcap_file: str) -> List[Dict]:
  """
  Reads QUIC packets from a PCAP file and parses them using the provided frame_parser.

  Args:
      pcap_file: Path to the PCAP file containing network traffic.

  Returns:
      A list of dictionaries, where each dictionary contains information about a parsed packet:
          - packet_info: Summary of the packet (from scapy).
          - parsed_frames: List of parsed frames for the QUIC packet.
          - result: Parsing result dictionary from the frame parser (may indicate errors or status).
  """
  
  parsed_data = []
  #for packet in sniff(offline=pcap_file):
  if UDP in packet:
        # Extract QUIC payload
        quic_payload = bytes(packet["UDP"])[8:]
        
        # Parse frames using provided functions
        payload_offset = ETH_HLEN + packet[IP].ihl + UDP_HLEN
        frames, result = parse_frames(bytearray(quic_payload), payload_offset=payload_offset)
        parsed_data.append({
            "packet_info": packet.summary(),
            "parsed_frames": frames,
            "result": result
        })
  return parsed_data

with open('quic_traffic.pcap', 'rb') as f:
    pcap_data = f.read()

# Loop through packets in the PCAP data
for packet in rdpcap("quic_traffic.pcap"):
    parsed_packets=parse_quic_packets(bytes(packet))
 

# Example usage
#parsed_packets = parse_quic_packets('quic_traffic.pcap')
#print(payload_offset)
#print(len(packet_bytearray))
#print(frame_len)


# Print or analyze the parsed data (packet info, frames, and results)
for packet_data in parsed_packets:
  print(f"Packet Info: {packet_data['packet_info']}")
  print(f"Parsed Frames: {packet_data['parsed_frames']}")
  print(f"Parsing Result: {packet_data['result']}")
  print("-" * 60)
